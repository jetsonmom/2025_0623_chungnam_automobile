# %% [markdown]
# <a href="https://colab.research.google.com/github/jetsonmom/2025_0623_chungnam_automobile/blob/main/0630_init%EC%97%90_%EA%B7%B8%EB%8F%99%EC%95%88_%EB%B0%B0%EC%9A%B4_%EB%82%B4%EC%9A%A9_%EC%A0%91%EB%AA%A9%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1번 코드. main함수 안에서 실행하기
#
# **핵심**: 이 코드는 가장 단순한 구조로, main 안에서 순차적으로 실행되고 함수 호출이 없어요! 위에서 아래로 쭉 실행되는 직선형 코드입니다.
#
# ## 실행 순서:
#
# 1. **프로그램 시작**: `if __name__ == "__main__":` 조건 확인 후 main 실행부 시작
#
# 2. **시스템 출력**:
# 3. **장애물 감지 시작**:
# `obstacles = []` 빈 리스트 생성
#
# 4. **센서 데이터 검사**:
# 5. **장애물 출력**:
# 6. **프로그램 종료**

# %%
# 센서 데이터 (거리 측정값, 단위: 미터)
sensors = {
    "앞": 8.0,
    "왼쪽": 15.0,
    "오른쪽": 4.0
}

# 안전 거리 설정
safe_distance = 10.0

if __name__ == "__main__":
    print("🚗 자율주행 장애물 감지 시스템")
    print("-" * 30)

    # 장애물 감지
    obstacles = []
    for direction, distance in sensors.items():
        if distance < safe_distance:
            obstacles.append(direction)

    print(f"\n🚨 감지된 장애물: {obstacles}")

# %% [markdown]
# 2번 코드. ## 실행 순서:
#
# 1. **프로그램 시작**: `if __name__ == "__main__":` 조건 확인 후 main 실행부 시작
#
# 2. **시스템 출력**:
# 3. **main에서 함수 호출**
#  `obstacles = detect_obstacles(sensors, safe_distance)`
#
# 4. **함수로 이동**: `def detect_obstacles(sensors, safe_distance):` 안으로 들어가서 실행
# 5. **return으로 값 반환**: `return obstacles` 로 `['앞', '오른쪽']` 리스트를 돌려줌
#
# 6. **main으로 돌아옴**:
# `obstacles = detect_obstacles(sensors, safe_distance)` 에서 `obstacles` 변수에 `['앞', '오른쪽']`가 저장됨
#
# 7. **장애물 출력**:
# `print(f"\n🚨 감지된 장애물: {obstacles}")`
#    - 결과: `🚨 감지된 장애물: ['앞', '오른쪽']`
#
# 8. **프로그램 종료**

# %%
# 센서 데이터 (거리 측정값, 단위: 미터)
sensors = {
    "앞": 8.0,
    "왼쪽": 15.0,
    "오른쪽": 4.0
}

# 안전 거리 설정
safe_distance = 10.0

def detect_obstacles(sensors, safe_distance):
    """장애물을 감지하는 함수"""
    obstacles = []
    for direction, distance in sensors.items():
        if distance < safe_distance:
            obstacles.append(direction)
    return obstacles

if __name__ == "__main__":
    print("🚗 자율주행 장애물 감지 시스템")
    print("-" * 30)

    # 장애물 감지 함수 호출
    obstacles = detect_obstacles(sensors, safe_distance)

    print(f"\n🚨 감지된 장애물: {obstacles}")

# %% [markdown]
# ## 실행 순서:
#
# 1. **프로그램 시작**: `if __name__ == "__main__":` 조건 확인 후 main 실행부 시작
#
# 2. **시스템 출력**:
# 3. **장애물 감지 시작**:
#  `obstacles = []` 빈 리스트 생성
# 4. **센서 데이터 검사**:
#    for 문장
# 5. **장애물 출력**:
# 6. **행동 결정 로직 실행**:
#  7. **행동 출력**:
#    - 결과: "좌회전"
#
# 8. **프로그램 종료**

# %%
# 센서 데이터 (거리 측정값, 단위: 미터)
sensors = {
    "앞": 8.0,
    "왼쪽": 15.0,
    "오른쪽": 4.0
}

# 안전 거리 설정
safe_distance = 10.0

if __name__ == "__main__":
    print("🚗 자율주행 장애물 감지 시스템")
    print("-" * 30)

    # 장애물 감지
    obstacles = []
    for direction, distance in sensors.items():
        if distance < safe_distance:
            obstacles.append(direction)

    print(f"\n🚨 감지된 장애물: {obstacles}")

    # 행동 결정
    if len(obstacles) == 0:
        action = "직진"
    elif "앞" in obstacles:
        if "왼쪽" not in obstacles:
            action = "좌회전"
        elif "오른쪽" not in obstacles:
            action = "우회전"
        else:
            action = "정지"
    else:
        action = "주의해서 직진"

    print(f"🎯 결정된 행동: {action}")

# %% [markdown]
# ## 실행 순서:
#
# 1. **프로그램 시작**: `if __name__ == "__main__":` 조건 확인 후 main 실행부 시작
#
# 2. **시스템 출력**:
#    ```python
#    print("🚗 자율주행 장애물 감지 시스템")
#    print("-" * 30)
#    ```
#
# 3. **main에서 함수 호출**:
# `obstacles = detect_obstacles(sensors, safe_distance)`
#
# 4. **함수로 이동**:
#  `def detect_obstacles(sensors, safe_distance):` 안으로 들어가서 실행
#    - for문으로 센서 데이터 검사
#    - 안전거리보다 가까운 방향들을 obstacles 리스트에 추가
#
# 5. **return으로 값 반환**: `return obstacles` 로 장애물 리스트를 돌려줌
#
# 6. **main으로 돌아옴**: `obstacles = detect_obstacles(sensors, safe_distance)` 에서 `obstacles` 변수에 결과가 저장됨
#
# 7. **장애물 출력**:
# `print(f"\n🚨 감지된 장애물: {obstacles}")`
#
# 8. **행동 결정 로직 실행**:
#  if-elif-else 문으로 상황에 맞는 행동 결정
#
# 9. **행동 출력**:
# `print(f"🎯 결정된 행동: {action}")`
#
# 10. **프로그램 종료**
#
# **핵심 포인트**:
#  함수는 호출되면 → 실행 → 결과 반환 → 호출한 곳으로 돌아가서 계속 진행!

# %%
# 센서 데이터 (거리 측정값, 단위: 미터)
sensors = {
    "앞": 8.0,
    "왼쪽": 15.0,
    "오른쪽": 4.0
}

# 안전 거리 설정
safe_distance = 10.0

def detect_obstacles(sensors, safe_distance):
    """장애물을 감지하는 함수"""
    obstacles = []
    for direction, distance in sensors.items():
        if distance < safe_distance:
            obstacles.append(direction)
    return obstacles

if __name__ == "__main__":
    print("🚗 자율주행 장애물 감지 시스템")
    print("-" * 30)

    # 장애물 감지
    obstacles = detect_obstacles(sensors, safe_distance)

    print(f"\n🚨 감지된 장애물: {obstacles}")

    # 행동 결정
    if len(obstacles) == 0:
        action = "직진"
    elif "앞" in obstacles:
        if "왼쪽" not in obstacles:
            action = "좌회전"
        elif "오른쪽" not in obstacles:
            action = "우회전"
        else:
            action = "정지"
    else:
        action = "주의해서 직진"

    print(f"🎯 결정된 행동: {action}")

# %% [markdown]
# main에서 호출:
# action = decide_action(obstacles)
# 함수로 이동: def decide_action(obstacles): 안으로 들어가서 실행
#
# return으로 값 반환: return action 으로 결과값을 돌려줌
#
# main으로 돌아옴:
#  action = decide_action(obstacles) 에서 action 변수에 값이 저장됨
#
# 다음 줄 실행: print(f"🎯 결정된 행동: {action}")

# %%
# 센서 데이터 (거리 측정값, 단위: 미터)
sensors = {
    "앞": 8.0,
    "왼쪽": 15.0,
    "오른쪽": 4.0
}

# 안전 거리 설정
safe_distance = 10.0

def detect_obstacles(sensors, safe_distance):
    """장애물을 감지하는 함수"""
    obstacles = []
    for direction, distance in sensors.items():
        if distance < safe_distance:
            obstacles.append(direction)
    return obstacles

def decide_action(obstacles):
    """장애물 정보를 바탕으로 행동을 결정하는 함수"""
    if len(obstacles) == 0:
        action = "직진"
    elif "앞" in obstacles:
        if "왼쪽" not in obstacles:
            action = "좌회전"
        elif "오른쪽" not in obstacles:
            action = "우회전"
        else:
            action = "정지"
    else:
        action = "주의해서 직진"
    return action

if __name__ == "__main__":
    print("🚗 자율주행 장애물 감지 시스템")
    print("-" * 30)

    # 장애물 감지
    obstacles = detect_obstacles(sensors, safe_distance)
    print(f"\n🚨 감지된 장애물: {obstacles}")

    # 행동 결정
    action = decide_action(obstacles)
    print(f"🎯 결정된 행동: {action}")
